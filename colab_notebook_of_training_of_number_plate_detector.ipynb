# %% [markdown]
# <a href="https://colab.research.google.com/github/imashutoshjha/YOLO_object_detection_pretrained_and_custom_all_projects/blob/master/colab_notebook_of_training_of_number_plate_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %%
# !apt-get update
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done

# %%
# %cd /content/
# Out:
# /content

# %%
# !unzip "/content/drive/MyDrive/Number_plate_detection/darknet.zip"
# Out:
# Archive:  /content/drive/MyDrive/Number_plate_detection/darknet.zip
#    creating: darknet/
#    creating: darknet/.git/
#   inflating: darknet/.git/description
#   inflating: darknet/.git/index
#   inflating: darknet/.git/HEAD
#   inflating: darknet/.git/config
#   inflating: darknet/.git/packed-refs
#    creating: darknet/.git/branches/
#    creating: darknet/.git/hooks/
#   inflating: darknet/.git/hooks/pre-applypatch.sample
#   inflating: darknet/.git/hooks/applypatch-msg.sample
#   inflating: darknet/.git/hooks/prepare-commit-msg.sample
#   inflating: darknet/.git/hooks/update.sample
#   inflating: darknet/.git/hooks/pre-commit.sample
#   inflating: darknet/.git/hooks/post-update.sample
#   inflating: darknet/.git/hooks/pre-push.sample
#   inflating: darknet/.git/hooks/pre-rebase.sample
#   inflating: darknet/.git/hooks/fsmonitor-watchman.sample
#   inflating: darknet/.git/hooks/pre-receive.sample
#   inflating: darknet/.git/hooks/commit-msg.sample
# ...

# %%
# !chmod +x /content/darknet
#To give executable permission to colab of darknet folder

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !make
#To compile
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# !rm /content/darknet/backup -r

# %%
# !ln -s /content/drive/'My Drive'/cov_weights/backup /content/darknet
#To generate to link between backup folder of drive and colab because colab may disconnect while training and data might be flushed so keep backup to drive.

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg yolov4.conv.137 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 280405, rewritten_bbox = 0.000000 %
#
#  723: 1.030916, 1.068829 avg loss, 0.000355 rate, 4.137792 seconds, 43380 images, 2.484642 hours left
# Loaded: 0.000062 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.735219), count: 8, class_loss = 0.563093, iou_loss = 5.270264, total_loss = 5.833357
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.819543), count: 11, class_loss = 0.627501, iou_loss = 4.300138, total_loss = 4.927639
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.790179), count: 1, class_loss = 0.012941, iou_loss = 0.047721, total_loss = 0.060663
#  total_bbox = 280425, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.599058), count: 18, class_loss = 3.206519, iou_loss = 18.353687, total_loss = 21.560207
# ...

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg /content/drive/'My Drive'/cov_weights/backup/yolov4_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 150264, rewritten_bbox = 0.000000 %
#
#  1193: 0.439757, 0.563600 avg loss, 0.001300 rate, 6.610000 seconds, 71580 images, 1.555944 hours left
# Loaded: 0.000042 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.735903), count: 18, class_loss = 1.509042, iou_loss = 32.538841, total_loss = 34.047882
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.781037), count: 32, class_loss = 1.985887, iou_loss = 13.616173, total_loss = 15.602060
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.765234), count: 12, class_loss = 0.742877, iou_loss = 1.290979, total_loss = 2.033856
#  total_bbox = 150326, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.791512), count: 17, class_loss = 0.355965, iou_loss = 42.018608, total_loss = 42.374569
# ...

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg /content/drive/'My Drive'/cov_weights/backup/yolov4_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 174709, rewritten_bbox = 0.000000 %
#
#  1653: 0.286788, 0.277720 avg loss, 0.000130 rate, 6.004907 seconds, 99180 images, 0.667687 hours left
# Loaded: 0.000067 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.851441), count: 11, class_loss = 0.031270, iou_loss = 25.504551, total_loss = 25.535820
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.887488), count: 10, class_loss = 0.210018, iou_loss = 4.645294, total_loss = 4.855312
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.801533), count: 3, class_loss = 0.001013, iou_loss = 0.129428, total_loss = 0.130441
#  total_bbox = 174733, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.864049), count: 3, class_loss = 0.000787, iou_loss = 3.901957, total_loss = 3.902744
# ...

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg /content/drive/'My Drive'/cov_weights/backup/yolov4_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 24005, rewritten_bbox = 0.000000 %
#
#  1763: 0.124727, 0.255919 avg loss, 0.000130 rate, 5.966643 seconds, 105780 images, 0.638206 hours left
# Loaded: 0.000058 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.854545), count: 14, class_loss = 0.607554, iou_loss = 19.464359, total_loss = 20.071915
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.821092), count: 34, class_loss = 0.948603, iou_loss = 11.076767, total_loss = 12.025370
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.816551), count: 9, class_loss = 0.109586, iou_loss = 0.800933, total_loss = 0.910519
#  total_bbox = 24062, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.796897), count: 30, class_loss = 2.313847, iou_loss = 71.678970, total_loss = 73.992821
# ...

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg /content/drive/'My Drive'/cov_weights/backup/yolov4_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.920183), count: 3, class_loss = 0.049647, iou_loss = 0.146104, total_loss = 0.195752
#  total_bbox = 38976, rewritten_bbox = 0.000000 %
#
#  1903: 0.177731, 0.243827 avg loss, 0.000013 rate, 4.171252 seconds, 114180 images, 0.336809 hours left
# Loaded: 0.000062 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.821344), count: 5, class_loss = 0.068826, iou_loss = 3.747152, total_loss = 3.815978
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.872111), count: 8, class_loss = 0.532010, iou_loss = 2.144906, total_loss = 2.676916
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.786013), count: 3, class_loss = 0.732504, iou_loss = 0.256697, total_loss = 0.989201
#  total_bbox = 38992, rewritten_bbox = 0.000000 %
# ...
