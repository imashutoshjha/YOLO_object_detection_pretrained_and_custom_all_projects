# %% [markdown]
# <a href="https://colab.research.google.com/github/imashutoshjha/YOLO_object_detection_pretrained_and_custom_all_projects/blob/master/Google_colab_code_of_custom_corona_virus_object_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Get the runtime details

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %% [markdown]
# Update the repo list

# %%
# !apt-get update
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# Unzip the darknet zip file to the /content folder

# %%
# !unzip "/content/drive/MyDrive/custom_cov_model/darknet.zip"
# Out:
# Archive:  /content/drive/MyDrive/custom_cov_model/darknet.zip
#    creating: darknet/
#   inflating: darknet/.gitignore
#   inflating: darknet/.travis.yml
#   inflating: darknet/CMakeLists.txt
#   inflating: darknet/DarknetConfig.cmake.in
#   inflating: darknet/LICENSE
#   inflating: darknet/yolov4.conv.137
#   inflating: darknet/README.md
#   inflating: darknet/build.ps1
#   inflating: darknet/build.sh
#   inflating: darknet/darknet.py
#   inflating: darknet/darknet_images.py
#   inflating: darknet/darknet_video.py
#   inflating: darknet/image_yolov3.sh
#   inflating: darknet/image_yolov4.sh
#   inflating: darknet/json_mjpeg_streams.sh
#   inflating: darknet/net_cam_v3.sh
#   inflating: darknet/net_cam_v4.sh
#   inflating: darknet/video_yolov3.sh
#   inflating: darknet/video_yolov4.sh
#   inflating: darknet/Makefile
#   inflating: darknet/yolov4.weights
#   inflating: darknet/cov_yolov4.cfg
#   inflating: darknet/yolov4.cfg
#    creating: darknet/.git/
# ...

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !make  #compilation of darknet
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
#output of the image is present at /content/darknet/predictions.jpg
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# **Create a symbolic link from runtime darknet folder to google drive backup folder with the name backup**

# %%
# !ln -s /content/drive/'My Drive'/cov_weights/backup /content/darknet

#ln -s existing-file-path-where-you-want-to-store-permanently new-file-name-we-will-send-file-during runtime
#this is because colab does not allow us to have gpu more than 12 hours so we need to keep backup because training may take sometime very long time.
#and darknet/backup is just dummy,it transfer all files to the backup of drive under cov_weights.
# Out:
# ln: failed to create symbolic link '/content/darknet/backup': File exists

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg yolov4.conv.137 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 199464, rewritten_bbox = 0.003509 %
#
#  153: 9.012800, 22.335573 avg loss, 0.000001 rate, 3.260553 seconds, 9180 images, 3.642729 hours left
# Loaded: 0.000044 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.233679), count: 48, class_loss = 12.633031, iou_loss = 3.273675, total_loss = 15.906706
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.377283), count: 90, class_loss = 21.566330, iou_loss = 3.925758, total_loss = 25.492088
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.304238), count: 25, class_loss = 6.959261, iou_loss = 0.182285, total_loss = 7.141546
#  total_bbox = 199627, rewritten_bbox = 0.003507 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.302039), count: 70, class_loss = 18.116430, iou_loss = 12.780787, total_loss = 30.897217
# ...

# %% [markdown]
# # **TO resume the training from the last training point**

# %%
# !./darknet detector train cov_data/cov.data yolov4.cfg /content/drive/'My Drive'/cov_weights/backup/yolov4_last.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 5, batch = 60, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...
